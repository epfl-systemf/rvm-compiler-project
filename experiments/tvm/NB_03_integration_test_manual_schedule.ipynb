# %%
# Imports

import tvm
from tvm import meta_schedule as ms
from tvm import relay
from tvm.script import tir as T
from tvm.tir import TensorIntrin

import numpy as np

# %%
@T.prim_func
def dot_product_relu_16x4_u8i8i32_desc(
    A: T.Buffer((4,), "uint8", offset_factor=1),
    B: T.Buffer((16, 4), "int8", offset_factor=1),
    C: T.Buffer((16,), "int32", offset_factor=1),
) -> None:
    with T.block("root"):
        T.reads(C[0:16], A[0:4], B[0:16, 0:4])
        T.writes(C[0:16])
        for i in T.serial(0, 16):
            for k in T.serial(0, 4):
                with T.block("update"):
                    vi, vk = T.axis.remap("SR", [i, k])
                    C[vi] = C[vi] + T.cast(A[vk], "int32") * T.cast(B[vi, vk], "int32")

# %%
@T.prim_func
def dot_product_relu_16x4_u8i8i32_avx512(
    A: T.Buffer((4,), "uint8", offset_factor=1),
    B: T.Buffer((16, 4), "int8", offset_factor=1),
    C: T.Buffer((16,), "int32", offset_factor=1),
) -> None:
    with T.block("root"):
        T.reads(C[0:16], A[0:4], B[0:16, 0:4])
        T.writes(C[0:16])

        A_u8x4 = A.vload([0], "uint8x4")
        A_i32 = T.reinterpret(A_u8x4, dtype="int32")
        A_brdcst = T.broadcast(A_i32, 16)
        A_u8x64 = T.reinterpret(A_brdcst, dtype="uint8x64")

        B_i8x64 = B.vload([0, 0], dtype="int8x64")

        Red = T.call_llvm_pure_intrin(
            T.llvm_lookup_intrinsic_id("llvm.x86.avx512.pmaddubs.w.512"),
            T.uint32(2),
            A_u8x64,
            B_i8x64,
            dtype="int16x32",
        )

        C[T.ramp(T.int32(0), 1, 16)] += T.call_llvm_pure_intrin(
            T.llvm_lookup_intrinsic_id("llvm.x86.avx512.pmaddw.d.512"),
            T.uint32(2),
            Red,
            T.int16x32(1),
            dtype="int32x16",
        )

# %%
SKYLAKE_AVX512_TARGET = "llvm -mcpu=skylake-avx512 -num-cores 4"

AVX512_DOT_16x4_INTRIN = "dot_16x4_avx512"

TensorIntrin.register(
    AVX512_DOT_16x4_INTRIN, dot_product_relu_16x4_u8i8i32_desc, dot_product_relu_16x4_u8i8i32_avx512
)

def _get_schedule_rules_for_x86(intrin):
    return [
        ms.schedule_rule.ApplyCustomRule(),
        ms.schedule_rule.AutoInline(
            into_producer=False,
            into_consumer=True,
            inline_const_tensor=True,
            disallow_if_then_else=True,
            require_injective=True,
            require_ordered=True,
            disallow_op=["tir.exp"],
        ),
        ms.schedule_rule.AddRFactor(max_jobs_per_core=16, max_innermost_factor=64),
        ms.schedule_rule.MultiLevelTilingWithIntrin(
            intrin,
            structure="SSRSRS",
            tile_binds=None,
            max_innermost_factor=64,
            vector_load_lens=None,
            reuse_read=None,
            reuse_write=ms.schedule_rule.ReuseType(
                req="may",
                levels=[1, 2],
                scope="global",
            ),
        ),
        ms.schedule_rule.MultiLevelTiling(
            structure="SSRSRS",
            tile_binds=None,
            max_innermost_factor=64,
            vector_load_lens=None,
            reuse_read=None,
            reuse_write=ms.schedule_rule.ReuseType(
                req="may",
                levels=[1, 2],
                scope="global",
            ),
        ),
        ms.schedule_rule.ParallelizeVectorizeUnroll(
            max_jobs_per_core=16,
            max_vectorize_extent=64,
            unroll_max_steps=[0, 16, 64, 512],
            unroll_explicit=True,
        ),
        ms.schedule_rule.RandomComputeLocation(),
    ]

SCH_RULES_FOR_AVX512 = _get_schedule_rules_for_x86(AVX512_DOT_16x4_INTRIN)

POSTPROCS_FOR_VNNI = [
    ms.postproc.DisallowDynamicLoop(),
    ms.postproc.RewriteParallelVectorizeUnroll(),
    ms.postproc.RewriteReductionBlock(),
    ms.postproc.RewriteTensorize(vectorize_init_loop=True),
]

# %%
#_test_dense("uint8", SCH_RULES_FOR_AVX512, POSTPROCS_FOR_VNNI, SKYLAKE_AVX512_TARGET)

"""dim_m, dim_n, dim_k = 1024, 1024, 1024
data_shape = (dim_m, dim_k)
weight_shape = (dim_n, dim_k)

weight_dtype = "int8"
out_dtype = "int32"
data_dtype = "uint8"

data = relay.var("data", shape=data_shape, dtype=data_dtype)
weight = relay.var("weight", shape=weight_shape, dtype=weight_dtype)
dense = relay.nn.dense(data, weight, out_dtype=out_dtype)

relay_mod = tvm.IRModule.from_expr(dense)

weight_np = np.random.uniform(1, 10, size=weight_shape).astype(weight_dtype)

params = {"weight": weight_np}
tune_tasks = list(
    filter(
        lambda task: "dense" in task.task_name,
        ms.relay_integration.extract_tasks(relay_mod, SKYLAKE_AVX512_TARGET, params),
    )
)"""

from tvm import te

N, M, L = 1024, 512, 64
# A = te.placeholder((N, L), name="A")
# B = te.placeholder((M, L), name="B")
# k = te.reduce_axis((0, L), name="k")
# C = te.compute((N, M), lambda i, j: te.sum(te.max(0, A[i, k] * B[j, k]), axis=k), name="C")

A = te.placeholder((L,), name='A', dtype='int8')
B = te.placeholder((M,L), name='B', dtype='uint8')
j = te.reduce_axis((0, L), 'j')

# Define the computation for matrix-vector multiplication
C = te.compute((M,), lambda i: te.sum(A[j] * B[i, j], axis=j), name='C')


func = te.create_prim_func([A,B,C])
print(func)
sch = tvm.tir.Schedule(func)

# %%
SCH_RULES_FOR_AVX512[3].apply(sch, sch.get_block("root"))

# %%
from tvm.tir.tensor_intrin.x86 import dot_product_16x4_u8i8i32_vnni

A_buf = tvm.tir.decl_buffer((4,), "uint8", "A")
B_buf = tvm.tir.decl_buffer((16, 4), "int8", "B")
C_buf = tvm.tir.decl_buffer((16,), "int32", "C")

target = "llvm -mcpu=skylake-avx512"
f = tvm.build(dot_product_16x4_u8i8i32_vnni, [A_buf, B_buf, C_buf], name="my_thing", target=target)

print(f.get_source())
# Out:
# error: InternalError: Check failed: (value_dtype.element_of() == n->dtype.element_of() && value_dtype.lanes() % n->dtype.lanes() == 0) is false: Cannot load int8x4 from buffer of int32
#  --> /home/julien/tvm/python/tvm/tir/tensor_intrin/x86.py:57:20
#     |
#  57 |          C_i32x16 = C.vload([0], dtype="int8x4")
#     |                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:269, in ExprEvaluator._visit(self, node)
#     268     else:
# --> 269         value = self._eval_expr(node.__class__(**fields))
#     270 except Exception as e:  # pylint: disable=broad-except,invalid-name
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:409, in ExprEvaluator._eval_expr(self, v)
#     397 """The doc AST expression node evaluating method.
#     398
#     399 Parameters
#    (...)
#     407     The evaluation result.
#     408 """
# --> 409 return _eval_expr(v, self.value_table)
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:498, in _eval_expr(node, dict_globals)
#     497 exe = compile(node, filename="<ast>", mode="eval")
# --> 498 return eval(exe, dict_globals)
#
# File <ast>:16
#
# File ~/tvm/python/tvm/tir/buffer.py:123, in Buffer.vload(self, begin, dtype)
#     122 dtype = dtype if dtype else self.dtype
# --> 123 return _ffi_api.BufferVLoad(self, begin, dtype)
#
# File ~/tvm/python/tvm/_ffi/_ctypes/packed_func.py:239, in PackedFuncBase.__call__(self, *args)
#     228 if (
#     229     _LIB.TVMFuncCall(
#     230         self.handle,
#    (...)
#     237     != 0
#     238 ):
# --> 239     raise_last_ffi_error()
#     240 _ = temp_args
#
# File ~/tvm/python/tvm/_ffi/base.py:481, in raise_last_ffi_error()
#     479 _LIB.TVMDropLastPythonError()
# --> 481 raise py_err
#
# InternalError: Traceback (most recent call last):
#   2: _ZN3tvm7runtime13PackedFuncObj
#   1: tvm::runtime::TypedPackedFunc<tvm::PrimExpr (tvm::tir::Buffer, tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType)>::AssignTypedLambda<tvm::runtime::Registry::set_body_method<tvm::tir::Buffer, tvm::PrimExpr, tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType>(tvm::PrimExpr (tvm::tir::Buffer::*)(tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType) const)::{lambda(tvm::tir::Buffer, tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType)#1}>(tvm::runtime::Registry::set_body_method<tvm::tir::Buffer, tvm::PrimExpr, tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType>(tvm::PrimExpr (tvm::tir::Buffer::*)(tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType) const)::{lambda(tvm::tir::Buffer, tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType)#1}, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}::operator()(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*) const
#   0: tvm::tir::Buffer::vload(tvm::runtime::Array<tvm::PrimExpr, void>, tvm::runtime::DataType) const
#   File "/home/julien/tvm/src/tir/ir/buffer.cc", line 406
# InternalError: Check failed: (value_dtype.element_of() == n->dtype.element_of() && value_dtype.lanes() % n->dtype.lanes() == 0) is false: Cannot load int8x4 from buffer of int32
#
# During handling of the above exception, another exception occurred:
#
# DiagnosticError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tvm.tir.tensor_intrin.x86 import dot_product_16x4_u8i8i32_vnni
#       3 A_buf = tvm.tir.decl_buffer((4,), "uint8", "A")
#       4 B_buf = tvm.tir.decl_buffer((16, 4), "int8", "B")
#
# File ~/tvm/python/tvm/tir/tensor_intrin/__init__.py:19
#       1 # Licensed to the Apache Software Foundation (ASF) under one
#       2 # or more contributor license agreements.  See the NOTICE file
#       3 # distributed with this work for additional information
#    (...)
#      16 # under the License.
#      17 # pylint: disable=unused-import
#      18 """Intrinsics for tensorization."""
# ---> 19 from . import arm_cpu, cuda, rocm, x86, hexagon
#
# File ~/tvm/python/tvm/tir/tensor_intrin/x86.py:43
#      38                     vi, vk = T.axis.remap("SR", [i, k])
#      39                     C[vi] = C[vi] + T.cast(A[vk], "int32") * T.cast(B[vi, vk], "int32")
#      42 @T.prim_func
# ---> 43 def dot_product_16x4_u8i8i32_vnni(
#      44     A: T.Buffer((4,), "uint8", offset_factor=1),
#      45     B: T.Buffer((16, 4), "int8", offset_factor=1),
#      46     C: T.Buffer((16,), "int32", offset_factor=1),
#      47 ) -> None:
#      48     with T.block("root"):
#      49         T.reads(C[0:16], A[0:4], B[0:16, 0:4])
#
# File ~/tvm/python/tvm/script/parser/tir/entry.py:69, in prim_func(func, private)
#      65     return f
#      67 if func is not None:
#      68     # no optional args given => use wrapper directly
# ---> 69     return decorator_wrapper(func)
#      70 else:
#      71     # if there is an optional arg given, return a new decorator
#      72     # that will then be invoked
#      73     setattr(decorator_wrapper, "dispatch_token", "tir")
#
# File ~/tvm/python/tvm/script/parser/tir/entry.py:63, in prim_func.<locals>.decorator_wrapper(func)
#      61 if utils.is_defined_in_class(outer_stack, func):
#      62     return func
# ---> 63 f = parse(func, utils.inspect_function_capture(func))
#      64 setattr(f, "__name__", func.__name__)
#      65 return f
#
# File ~/tvm/python/tvm/script/parser/core/entry.py:76, in parse(program, extra_vars)
#      74 with IRBuilder() as builder:
#      75     try:
# ---> 76         parser.parse(extra_vars=extra_vars)
#      77     except ParserError as err:
#      78         parser.report_error(err.node, err.args[0])
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:375, in Parser.parse(self, extra_vars)
#     373     self.var_table.add(k, v)
#     374 node = self.diag.source.as_ast()
# --> 375 self.visit(node)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:564, in Parser.visit(self, node)
#     562     raise NotImplementedError(f"Visitor of AST node is not implemented: {name}")
#     563 try:
# --> 564     func(node)
#     565 except DiagnosticError:
#     566     raise
#
# File ~/tvm/python/tvm/script/parser/core/doc.py:257, in NodeVisitor.generic_visit(self, node)
#     255     pass
#     256 elif isinstance(value, (doc.AST, list, tuple)):
# --> 257     self.visit(value)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:552, in Parser.visit(self, node)
#     550 if isinstance(node, (list, tuple)):
#     551     for item in node:
# --> 552         self.visit(item)
#     553     return
#     554 if not isinstance(node, doc.AST):
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:564, in Parser.visit(self, node)
#     562     raise NotImplementedError(f"Visitor of AST node is not implemented: {name}")
#     563 try:
# --> 564     func(node)
#     565 except DiagnosticError:
#     566     raise
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:622, in Parser.visit_FunctionDef(self, node)
#     618 post_func = dispatch.get(
#     619     token=current_token, type_name="post_token_switch", default=_do_nothing
#     620 )
#     621 pre_func(self, node)
# --> 622 _dispatch_wrapper(func)(self, node)
#     623 post_func(self, node)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:307, in _dispatch_wrapper.<locals>._wrapper(self, node)
#     305 def _wrapper(self: "Parser", node: doc.AST) -> None:
#     306     try:
# --> 307         return func(self, node)
#     308     except DiagnosticError:
#     309         raise
#
# File ~/tvm/python/tvm/script/parser/tir/parser.py:412, in visit_function_def(self, node)
#     410                 param = T.arg(arg.arg, ann)
#     411                 self.var_table.add(arg.arg, param)
# --> 412             self.visit_body(node.body)
#     413 self.function_annotations = supplied_annotation
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:585, in Parser.visit_body(self, node)
#     572 """The general body visiting method.
#     573
#     574 Parameters
#    (...)
#     582     The visiting result.
#     583 """
#     584 for stmt in node:
# --> 585     self.visit(stmt)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:564, in Parser.visit(self, node)
#     562     raise NotImplementedError(f"Visitor of AST node is not implemented: {name}")
#     563 try:
# --> 564     func(node)
#     565 except DiagnosticError:
#     566     raise
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:706, in Parser.visit_With(self, node)
#     693 def visit_With(self, node: doc.With) -> Any:  # pylint: disable=invalid-name
#     694     """The general with visiting method.
#     695
#     696     Parameters
#    (...)
#     704         The visiting result.
#     705     """
# --> 706     return _dispatch(self, "With")(self, node)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:307, in _dispatch_wrapper.<locals>._wrapper(self, node)
#     305 def _wrapper(self: "Parser", node: doc.AST) -> None:
#     306     try:
# --> 307         return func(self, node)
#     308     except DiagnosticError:
#     309         raise
#
# File ~/tvm/python/tvm/script/parser/tir/parser.py:363, in visit_with(self, node)
#     361     if item.optional_vars is not None:
#     362         self.eval_assign(target=item.optional_vars, source=rhs, bind_value=bind_with_value)
# --> 363 self.visit_body(node.body)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:585, in Parser.visit_body(self, node)
#     572 """The general body visiting method.
#     573
#     574 Parameters
#    (...)
#     582     The visiting result.
#     583 """
#     584 for stmt in node:
# --> 585     self.visit(stmt)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:564, in Parser.visit(self, node)
#     562     raise NotImplementedError(f"Visitor of AST node is not implemented: {name}")
#     563 try:
# --> 564     func(node)
#     565 except DiagnosticError:
#     566     raise
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:721, in Parser.visit_Assign(self, node)
#     708 def visit_Assign(self, node: doc.Assign) -> Any:  # pylint: disable=invalid-name
#     709     """The general assign visiting method.
#     710
#     711     Parameters
#    (...)
#     719         The visiting result.
#     720     """
# --> 721     return _dispatch(self, "Assign")(self, node)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:307, in _dispatch_wrapper.<locals>._wrapper(self, node)
#     305 def _wrapper(self: "Parser", node: doc.AST) -> None:
#     306     try:
# --> 307         return func(self, node)
#     308     except DiagnosticError:
#     309         raise
#
# File ~/tvm/python/tvm/script/parser/tir/parser.py:251, in visit_assign(self, node)
#     239         if not s.step and s.upper and s.lower:
#     240             s.step = doc.Constant(
#     241                 1,
#     242                 None,
#    (...)
#     248                 s.upper.end_col_offset + 2,
#     249             )
# --> 251 rhs = self.eval_expr(node.value)
#     252 if isinstance(lhs, doc.Subscript):
#     253     if isinstance(lhs.slice, doc.Tuple):
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:433, in Parser.eval_expr(self, node, extra_vars)
#     431         var_values[k] = v
#     432 var_values[ScriptMacro.parser_object_name] = self
# --> 433 return eval_expr(self, node, var_values)
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:438, in eval_expr(parser, node, dict_globals)
#     436 if dict_globals is not None:
#     437     value_table.update(dict_globals)
# --> 438 return ExprEvaluator.eval(parser, value_table, node)
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:118, in ExprEvaluator.eval(parser, value_table, node)
#      99 """Expression evaluation for TVMScript parser.
#     100
#     101 Parameters
#    (...)
#     115     The evaluation result.
#     116 """
#     117 self = ExprEvaluator(parser, value_table)
# --> 118 result = self._visit(node)  # pylint: disable=protected-access
#     119 if isinstance(result, doc.Name):
#     120     if result.id in self.value_table:
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:271, in ExprEvaluator._visit(self, node)
#     269         value = self._eval_expr(node.__class__(**fields))
#     270 except Exception as e:  # pylint: disable=broad-except,invalid-name
# --> 271     self.parser.report_error(node, e)
#     272 return self._add_intermediate_result(value)
#
# File ~/tvm/python/tvm/script/parser/core/parser.py:535, in Parser.report_error(self, node, err)
#     533 if isinstance(err, Exception):
#     534     diag_err = diag_err.with_traceback(err.__traceback__)
# --> 535 raise diag_err
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:269, in ExprEvaluator._visit(self, node)
#     267         value = self._eval_slice(fields)
#     268     else:
# --> 269         value = self._eval_expr(node.__class__(**fields))
#     270 except Exception as e:  # pylint: disable=broad-except,invalid-name
#     271     self.parser.report_error(node, e)
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:409, in ExprEvaluator._eval_expr(self, v)
#     396 def _eval_expr(self, v: Any) -> Any:
#     397     """The doc AST expression node evaluating method.
#     398
#     399     Parameters
#    (...)
#     407         The evaluation result.
#     408     """
# --> 409     return _eval_expr(v, self.value_table)
#
# File ~/tvm/python/tvm/script/parser/core/evaluator.py:498, in _eval_expr(node, dict_globals)
#     496 node = ast.fix_missing_locations(node)
#     497 exe = compile(node, filename="<ast>", mode="eval")
# --> 498 return eval(exe, dict_globals)
#
# File <ast>:16
#
# File ~/tvm/python/tvm/tir/buffer.py:123, in Buffer.vload(self, begin, dtype)
#     121 begin = (begin,) if isinstance(begin, (int, PrimExpr)) else begin
#     122 dtype = dtype if dtype else self.dtype
# --> 123 return _ffi_api.BufferVLoad(self, begin, dtype)
#
# File ~/tvm/python/tvm/_ffi/_ctypes/packed_func.py:239, in PackedFuncBase.__call__(self, *args)
#     227 ret_tcode = ctypes.c_int()
#     228 if (
#     229     _LIB.TVMFuncCall(
#     230         self.handle,
#    (...)
#     237     != 0
#     238 ):
# --> 239     raise_last_ffi_error()
#     240 _ = temp_args
#     241 _ = args
#
# File ~/tvm/python/tvm/_ffi/base.py:481, in raise_last_ffi_error()
#     475 # The exception PyObject may contain a large amount of state,
#     476 # including all stack frames that may be inspected in a later
#     477 # PDB post-mortem.  Therefore, we must make sure to remove the
#     478 # underlying PyObject* from the C++ side after we retrieve it.
#     479 _LIB.TVMDropLastPythonError()
# --> 481 raise py_err
#
# DiagnosticError: Traceback (most recent call last):
#   1: tvm::runtime::PackedFuncObj::Extractor<tvm::runtime::PackedFuncSubObj<tvm::runtime::TypedPackedFunc<void (tvm::DiagnosticContext)>::AssignTypedLambda<tvm::{lambda(tvm::DiagnosticContext)#9}>(tvm::{lambda(tvm::DiagnosticContext)#9}, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}> >::Call(tvm::runtime::PackedFuncObj const*, tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)
#   0: tvm::DiagnosticContext::Render()
#   File "/home/julien/tvm/src/ir/diagnostic.cc", line 131
# DiagnosticError: one or more error diagnostics were emitted, please check diagnostic render for output.

# %%
import tvm
from tvm import te, tir

# Define your PrimFunc (myfun)
A = te.placeholder((10,), name='A')
B = te.placeholder((10,), name='B')
C = te.compute((10,), lambda i: A[i] + B[i], name='C')
myfun = tir.PrimFunc([A, B], [C])

# Create a target (specify the target architecture)
target = "llvm"

# Build the function
f = tvm.build(myfun, target=target)

# Now, you can run the compiled function with appropriate input data
a_np = np.random.rand(10).astype('float32')
b_np = np.random.rand(10).astype('float32')
c_np = np.zeros(10, dtype='float32')
f(a_np, b_np, c_np)
